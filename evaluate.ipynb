# %%
from importlib import reload
from utils import metrics
reload(metrics)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %config InlineBackend.figure_format = "retina"

# %%
file_name = "03312359_ResNet50_NE_20_BS_32_LR_0.0001"
cls_eval = metrics.ClassificationEvaluator(file_name)
cls_eval.predict()

# %%
scores = cls_eval.evaluation_score()
for k, v in scores.items():
    print(f"{k}: {v:.4f}")
# Out:
# Accuracy: 0.9250
# Precision: 0.9515
# Recall: 0.9074
# F1-Score: 0.9289

# %%
cls_eval.training_curve()

# %%
cls_eval.roc_curve()
# Out:
# AUC: 0.9852053140096618

# %%
cls_eval.pr_curve()

# %%
cls_eval.confusion_matrix()

# %%
import glob

py_list = glob.glob("**/*.py", recursive=True)

lines = 0
for file in py_list:
    with open(file, "r") as f:
        lines += sum(1 for line in f if line.strip())

lines
# Out:
# 869

# %%
gc = metrics.GradCAM(file_name)

# %%
gc.cam_examples()

# %%
# gc.cam_test_dataset()
